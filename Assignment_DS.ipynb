# %% [markdown]
# <a href="https://colab.research.google.com/github/areebasharif441-ship-it/My-First-Repo/blob/main/Assignment_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/sample_data/ecommerce_sales.csv")

# %%
df_shape=df.shape
print(df.shape)
# Out:
# (2500, 10)

# %%
df_describe = df.describe()
print(df_describe)
# Out:
#          order_id        price     quantity  discount_applied  shipping_cost
# count  2500.00000  2500.000000  2500.000000       2245.000000    2500.000000
# mean   2249.50000   142.624180     3.018400          0.050646       3.537484
# std     721.83216   118.386167     1.428453          0.063177       4.437376
# min    1000.00000     3.040000     1.000000          0.000000       0.000000
# 25%    1624.75000    47.490000     2.000000          0.000000       0.000000
# 50%    2249.50000   114.385000     3.000000          0.000000       0.000000
# 75%    2874.25000   197.502500     4.000000          0.100000       5.292500
# max    3499.00000   499.160000     5.000000          0.200000      14.990000

# %%
unique_categories_count = df['category'].nunique()
print(unique_categories_count)
# Out:
# 5

# %%
has_missing = df.isnull().sum().sum() > 0
print(has_missing)
# Out:
# True

# %%
gross_cost_array = (df['price'] * df['quantity']).values
print(gross_cost_array)
# Out:
# [ 728.64  700.32  624.7  ...  147.48  397.47 1872.16]

# %%
payment_pivot = pd.pivot_table(
    df,
    values='price',
    index='payment_method',
    columns='category',
    aggfunc='sum'
)
print(payment_pivot)
# Out:
# category         Apparel  Electronics   Fitness  Groceries      Home
# payment_method
# Credit Card     11561.96     50556.60  10745.23     971.98  19653.87
# Debit Card      12348.76     49095.18   9091.34     879.85  17161.65
# Gift Card       12899.80     43492.95  11698.32    1317.75  21543.20
# PayPal          10987.49     39897.50   9704.09     980.43  21972.50

# %%
df['total'] = df['price'] * df['quantity']
premium_orders = df[df['total'] > 1000]
print(df['total'])
# Out:
# 0        728.64
# 1        700.32
# 2        624.70
# 3        306.02
# 4       1016.30
#          ...
# 2495     869.25
# 2496     344.62
# 2497     147.48
# 2498     397.47
# 2499    1872.16
# Name: total, Length: 2500, dtype: float64
